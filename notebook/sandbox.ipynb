# %%
import pandas as pd
import fastf1

# %%
df = fastf1.get_event_schedule(2023)
df.head(10)
# Out:
#    RoundNumber        Country   Location  \
# 0            0        Bahrain     Sakhir
# 1            1        Bahrain     Sakhir
# 2            2   Saudi Arabia     Jeddah
# 3            3      Australia  Melbourne
# 4            4     Azerbaijan       Baku
# 5            5  United States      Miami
# 6            6         Monaco     Monaco
# 7            7          Spain  Barcelona
# 8            8         Canada   Montréal
# 9            9        Austria  Spielberg
#
#                                    OfficialEventName  EventDate  \
# 0           FORMULA 1 ARAMCO PRE-SEASON TESTING 2023 2023-02-25
# 1         FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2023 2023-03-05
# 2        FORMULA 1 STC SAUDI ARABIAN GRAND PRIX 2023 2023-03-19
# 3         FORMULA 1 ROLEX AUSTRALIAN GRAND PRIX 2023 2023-04-02
# 4               FORMULA 1 AZERBAIJAN GRAND PRIX 2023 2023-04-30
# 5         FORMULA 1 CRYPTO.COM MIAMI GRAND PRIX 2023 2023-05-07
# ...

# %%
df_to_melt = df[['RoundNumber','EventName','Session1','Session2','Session3','Session4','Session5']]
df_unpivot = pd.melt(df_to_melt, id_vars=['RoundNumber','EventName'], value_vars=['Session1','Session2','Session3','Session4','Session5'])
df_unpivot.sort_values('RoundNumber')
# Out:
#      RoundNumber             EventName  variable       value
# 0              0    Pre-Season Testing  Session1  Practice 1
# 23             0    Pre-Season Testing  Session2  Practice 2
# 92             0    Pre-Season Testing  Session5        None
# 46             0    Pre-Season Testing  Session3  Practice 3
# 69             0    Pre-Season Testing  Session4        None
# ..           ...                   ...       ...         ...
# 45            22  Abu Dhabi Grand Prix  Session2  Practice 2
# 68            22  Abu Dhabi Grand Prix  Session3  Practice 3
# 22            22  Abu Dhabi Grand Prix  Session1  Practice 1
# 91            22  Abu Dhabi Grand Prix  Session4  Qualifying
# 114           22  Abu Dhabi Grand Prix  Session5        Race
#
# [115 rows x 4 columns]

# %%
df_unpivot[df_unpivot['EventName']=='Pre-Season Testing']
# Out:
#     RoundNumber           EventName  variable       value
# 0             0  Pre-Season Testing  Session1  Practice 1
# 23            0  Pre-Season Testing  Session2  Practice 2
# 46            0  Pre-Season Testing  Session3  Practice 3
# 69            0  Pre-Season Testing  Session4        None
# 92            0  Pre-Season Testing  Session5        None

# %%
session = fastf1.get_session(2023, 'Miami Grand Prix', 'Practice 1')
session.load(telemetry=False, laps=False, weather=False)

# %%
session.results.dtypes
